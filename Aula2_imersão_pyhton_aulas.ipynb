# %% [markdown]
# <a href="https://colab.research.google.com/github/rulio-cruz/imers-o_python_alura/blob/main/Aula2_imers%C3%A3o_pyhton_aulas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 2 importação

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel("/content/base_aula.xlsx",sheet_name="Principal")
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ...  Variação $.2  \
# 0           2.26         15.97      9.18      9.56  ...  1.081515e+08
# 1         -12.11         50.56      6.66      6.86  ... -1.043592e+09
# 2           7.64         77.55     40.81     42.34  ...  7.087773e+09
# 3          -4.89         18.85     51.89     53.17  ... -1.859212e+09
# 4          -3.66         20.70     36.37     37.32  ... -2.645988e+08
# ..           ...           ...       ...       ...  ...           ...
# 76        -13.98        -32.72     10.70     11.08  ... -9.294602e+08
# 77        -23.55        -85.74      8.67      8.95  ... -2.541781e+08
# 78        -11.57         -2.77     56.04     58.90  ... -6.278141e+09
# 79        -12.29        -36.83      3.05      3.23  ... -2.260905e+08
# 80        -34.00        -25.44      5.51      6.02  ... -6.044039e+08
#
#     Resultado.2  Variação Ano %  Valor Inicial (R$).2  Variação $.3  \
# 0         Subiu          0.0226              9.290045  1.081515e+08
# 1        Desceu         -0.1211              7.759700 -1.043592e+09
# 2         Subiu          0.0764             38.981791  7.087773e+09
# 3        Desceu         -0.0489             55.630323 -1.859212e+09
# 4        Desceu         -0.0366             38.509446 -2.645988e+08
# ..          ...             ...                   ...           ...
# 76       Desceu         -0.1398             12.450593 -9.294602e+08
# 77       Desceu         -0.2355             11.379987 -2.541781e+08
# 78       Desceu         -0.1157             63.598326 -6.278141e+09
# 79       Desceu         -0.1229              3.500171 -2.260905e+08
# 80       Desceu         -0.3400              8.969697 -6.044039e+08
#
#    Resultado.3 Varição 12M Valor Inicial (R$).3  Variação $.4 Resultado.4
# 0        Subiu      0.1597             8.191774  6.738901e+08       Subiu
# 1       Desceu      0.5056             4.529756  2.543452e+09       Subiu
# 2        Subiu      0.7755            23.632780  4.361654e+10       Subiu
# 3       Desceu      0.1885            44.518300  5.735331e+09       Subiu
# 4       Desceu      0.2070            30.737365  1.194474e+09       Subiu
# ..         ...         ...                  ...           ...         ...
# 76      Desceu     -0.3272            15.918549 -2.781316e+09      Desceu
# 77      Desceu     -0.8574            61.009818 -4.961222e+09      Desceu
# 78      Desceu     -0.0277            57.842230 -1.367026e+09      Desceu
# 79      Desceu     -0.3683             4.859902 -9.407416e+08      Desceu
# 80      Desceu     -0.2544             7.939914 -4.003165e+08      Desceu
#
# [81 rows x 36 columns]

# %%
df_Total_de_acoes = pd.read_excel("/content/base_aula.xlsx",sheet_name="Total_de_acoes")
df_Total_de_acoesdf_Total_de_acoes = pd.read_excel("/content/base_aula.xlsx",sheet_name="Total_de_acoes")
df_Total_de_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_Ticker = pd.read_excel("/content/base_aula.xlsx",sheet_name="Ticker")
df_Ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_ChatGPTGEMINI = pd.read_excel("/content/base_aula.xlsx",sheet_name="ChatGPTGEMINI")
df_ChatGPTGEMINI
# Out:
#    Nome da Empresa                     Segmento  Idade (Anos)
# 0         Usiminas                   Siderurgia            66
# 1    CSN Mineração                    Mineração            80
# 2        Petrobras               Petróleo e Gás            72
# 3           Suzano             Papel e Celulose            94
# 4     CPFL Energia             Energia Elétrica           114
# ..             ...                          ...           ...
# 67           Assaí            Varejo Atacadista            33
# 68              B3             Bolsa de Valores           132
# 69          Hypera                 Farmacêutica            54
# 70    São Martinho  Produção de Açúcar e Álcool            88
# 71         Hapvida                        Saúde            22
#
# [72 rows x 3 columns]

# %%
df_principal = df_principal[{'Ativo','Data','Último (R$)','Var. Dia (%)'}].copy()
df_principal
# Out:
# <ipython-input-9-c95fdb5275b5>:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df_principal = df_principal[{'Ativo','Data','Último (R$)','Var. Dia (%)'}].copy()
#          Data  Var. Dia (%)  Ativo  Último (R$)
# 0  2024-01-26          5.20  USIM5         9.50
# 1  2024-01-26          2.40  CMIN3         6.82
# 2  2024-01-26          2.19  PETR3        41.96
# 3  2024-01-26          2.04  SUZB3        52.91
# 4  2024-01-26          2.03  CPFE3        37.10
# ..        ...           ...    ...          ...
# 76 2024-01-26         -2.45  CRFB3        10.71
# 77 2024-01-26         -2.46  BHIA3         8.70
# 78 2024-01-26         -3.63  RENT3        56.24
# 79 2024-01-26         -4.36  CVCB3         3.07
# 80 2024-01-26         -8.07  GOLL4         5.92
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)':'valor_final','Var. Dia (%)':'var_dia_pct'}).copy()
df_principal
# Out:
#          Data  var_dia_pct  Ativo  valor_final
# 0  2024-01-26         5.20  USIM5         9.50
# 1  2024-01-26         2.40  CMIN3         6.82
# 2  2024-01-26         2.19  PETR3        41.96
# 3  2024-01-26         2.04  SUZB3        52.91
# 4  2024-01-26         2.03  CPFE3        37.10
# ..        ...          ...    ...          ...
# 76 2024-01-26        -2.45  CRFB3        10.71
# 77 2024-01-26        -2.46  BHIA3         8.70
# 78 2024-01-26        -3.63  RENT3        56.24
# 79 2024-01-26        -4.36  CVCB3         3.07
# 80 2024-01-26        -8.07  GOLL4         5.92
#
# [81 rows x 4 columns]

# %%
df_principal['Var_pct'] = df_principal['var_dia_pct'] / 100
df_principal['valor_inicial'] = df_principal['valor_final'] / (df_principal['Var_pct'] + 1)
df_principal
# Out:
#          Data  var_dia_pct  Ativo  valor_final  Var_pct  valor_inicial
# 0  2024-01-26         5.20  USIM5         9.50   0.0520       9.030418
# 1  2024-01-26         2.40  CMIN3         6.82   0.0240       6.660156
# 2  2024-01-26         2.19  PETR3        41.96   0.0219      41.060769
# 3  2024-01-26         2.04  SUZB3        52.91   0.0204      51.852215
# 4  2024-01-26         2.03  CPFE3        37.10   0.0203      36.361854
# ..        ...          ...    ...          ...      ...            ...
# 76 2024-01-26        -2.45  CRFB3        10.71  -0.0245      10.978985
# 77 2024-01-26        -2.46  BHIA3         8.70  -0.0246       8.919418
# 78 2024-01-26        -3.63  RENT3        56.24  -0.0363      58.358410
# 79 2024-01-26        -4.36  CVCB3         3.07  -0.0436       3.209954
# 80 2024-01-26        -8.07  GOLL4         5.92  -0.0807       6.439682
#
# [81 rows x 6 columns]

# %%
df_principal = df_principal.merge(df_Total_de_acoes, left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#          Data  var_dia_pct  Ativo  valor_final  Var_pct  valor_inicial Código  \
# 0  2024-01-26         5.20  USIM5         9.50   0.0520       9.030418  USIM5
# 1  2024-01-26         2.40  CMIN3         6.82   0.0240       6.660156  CMIN3
# 2  2024-01-26         2.19  PETR3        41.96   0.0219      41.060769  PETR3
# 3  2024-01-26         2.04  SUZB3        52.91   0.0204      51.852215  SUZB3
# 4  2024-01-26         2.03  CPFE3        37.10   0.0203      36.361854  CPFE3
# ..        ...          ...    ...          ...      ...            ...    ...
# 76 2024-01-26        -2.45  CRFB3        10.71  -0.0245      10.978985  CRFB3
# 77 2024-01-26        -2.46  BHIA3         8.70  -0.0246       8.919418  BHIA3
# 78 2024-01-26        -3.63  RENT3        56.24  -0.0363      58.358410  RENT3
# 79 2024-01-26        -4.36  CVCB3         3.07  -0.0436       3.209954  CVCB3
# 80 2024-01-26        -8.07  GOLL4         5.92  -0.0807       6.439682  GOLL4
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.drop(columns=['Código'])
df_principal
# Out:
#          Data  var_dia_pct  Ativo  valor_final  Var_pct  valor_inicial  \
# 0  2024-01-26         5.20  USIM5         9.50   0.0520       9.030418
# 1  2024-01-26         2.40  CMIN3         6.82   0.0240       6.660156
# 2  2024-01-26         2.19  PETR3        41.96   0.0219      41.060769
# 3  2024-01-26         2.04  SUZB3        52.91   0.0204      51.852215
# 4  2024-01-26         2.03  CPFE3        37.10   0.0203      36.361854
# ..        ...          ...    ...          ...      ...            ...
# 76 2024-01-26        -2.45  CRFB3        10.71  -0.0245      10.978985
# 77 2024-01-26        -2.46  BHIA3         8.70  -0.0246       8.919418
# 78 2024-01-26        -3.63  RENT3        56.24  -0.0363      58.358410
# 79 2024-01-26        -4.36  CVCB3         3.07  -0.0436       3.209954
# 80 2024-01-26        -8.07  GOLL4         5.92  -0.0807       6.439682
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 7 columns]

# %%
df_principal['variacao_rs'] = (df_principal['valor_final'] - df_principal['valor_inicial']) * df_principal['Qtde. Teórica']
df_principal
# Out:
#          Data  var_dia_pct  Ativo  valor_final  Var_pct  valor_inicial  \
# 0  2024-01-26         5.20  USIM5         9.50   0.0520       9.030418
# 1  2024-01-26         2.40  CMIN3         6.82   0.0240       6.660156
# 2  2024-01-26         2.19  PETR3        41.96   0.0219      41.060769
# 3  2024-01-26         2.04  SUZB3        52.91   0.0204      51.852215
# 4  2024-01-26         2.03  CPFE3        37.10   0.0203      36.361854
# ..        ...          ...    ...          ...      ...            ...
# 76 2024-01-26        -2.45  CRFB3        10.71  -0.0245      10.978985
# 77 2024-01-26        -2.46  BHIA3         8.70  -0.0246       8.919418
# 78 2024-01-26        -3.63  RENT3        56.24  -0.0363      58.358410
# 79 2024-01-26        -4.36  CVCB3         3.07  -0.0436       3.209954
# 80 2024-01-26        -8.07  GOLL4         5.92  -0.0807       6.439682
#
#     Qtde. Teórica   variacao_rs
# 0    5.151174e+08  2.418897e+08
# 1    1.110559e+09  1.775160e+08
# 2    2.379878e+09  2.140059e+09
# 3    6.834528e+08  7.229463e+08
# 4    1.877325e+08  1.385740e+08
# ..            ...           ...
# 76   5.339906e+08 -1.436355e+08
# 77   9.484305e+07 -2.081024e+07
# 78   8.532023e+08 -1.807433e+09
# 79   5.255828e+08 -7.355741e+07
# 80   1.981849e+08 -1.029932e+08
#
# [81 rows x 8 columns]

# %%
pd.options.display.float_format='{:.2f}'.format

# %%
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#          Data  var_dia_pct  Ativo  valor_final  Var_pct  valor_inicial  \
# 0  2024-01-26         5.20  USIM5         9.50     0.05           9.03
# 1  2024-01-26         2.40  CMIN3         6.82     0.02           6.66
# 2  2024-01-26         2.19  PETR3        41.96     0.02          41.06
# 3  2024-01-26         2.04  SUZB3        52.91     0.02          51.85
# 4  2024-01-26         2.03  CPFE3        37.10     0.02          36.36
# ..        ...          ...    ...          ...      ...            ...
# 76 2024-01-26        -2.45  CRFB3        10.71    -0.02          10.98
# 77 2024-01-26        -2.46  BHIA3         8.70    -0.02           8.92
# 78 2024-01-26        -3.63  RENT3        56.24    -0.04          58.36
# 79 2024-01-26        -4.36  CVCB3         3.07    -0.04           3.21
# 80 2024-01-26        -8.07  GOLL4         5.92    -0.08           6.44
#
#     Qtde. Teórica    variacao_rs
# 0       515117391   241889725.43
# 1      1110559345   177515970.30
# 2      2379877655  2140059393.53
# 3       683452836   722946282.71
# 4       187732538   138573955.06
# ..            ...            ...
# 76      533990587  -143635530.57
# 77       94843047   -20810240.84
# 78      853202347 -1807432634.46
# 79      525582771   -73557408.06
# 80      198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica':'qtd_teorica'}).copy()
df_principal
# Out:
#          Data  var_dia_pct  Ativo  valor_final  Var_pct  valor_inicial  \
# 0  2024-01-26         5.20  USIM5         9.50     0.05           9.03
# 1  2024-01-26         2.40  CMIN3         6.82     0.02           6.66
# 2  2024-01-26         2.19  PETR3        41.96     0.02          41.06
# 3  2024-01-26         2.04  SUZB3        52.91     0.02          51.85
# 4  2024-01-26         2.03  CPFE3        37.10     0.02          36.36
# ..        ...          ...    ...          ...      ...            ...
# 76 2024-01-26        -2.45  CRFB3        10.71    -0.02          10.98
# 77 2024-01-26        -2.46  BHIA3         8.70    -0.02           8.92
# 78 2024-01-26        -3.63  RENT3        56.24    -0.04          58.36
# 79 2024-01-26        -4.36  CVCB3         3.07    -0.04           3.21
# 80 2024-01-26        -8.07  GOLL4         5.92    -0.08           6.44
#
#     qtd_teorica    variacao_rs
# 0     515117391   241889725.43
# 1    1110559345   177515970.30
# 2    2379877655  2140059393.53
# 3     683452836   722946282.71
# 4     187732538   138573955.06
# ..          ...            ...
# 76    533990587  -143635530.57
# 77     94843047   -20810240.84
# 78    853202347 -1807432634.46
# 79    525582771   -73557408.06
# 80    198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Resultado'] = df_principal['variacao_rs'].apply(lambda x:'Subiu' if x > 0 else ('Desceu' if x < 0 else 'Estável'))
df_principal
# Out:
#          Data  var_dia_pct  Ativo  valor_final  Var_pct  valor_inicial  \
# 0  2024-01-26         5.20  USIM5         9.50     0.05           9.03
# 1  2024-01-26         2.40  CMIN3         6.82     0.02           6.66
# 2  2024-01-26         2.19  PETR3        41.96     0.02          41.06
# 3  2024-01-26         2.04  SUZB3        52.91     0.02          51.85
# 4  2024-01-26         2.03  CPFE3        37.10     0.02          36.36
# ..        ...          ...    ...          ...      ...            ...
# 76 2024-01-26        -2.45  CRFB3        10.71    -0.02          10.98
# 77 2024-01-26        -2.46  BHIA3         8.70    -0.02           8.92
# 78 2024-01-26        -3.63  RENT3        56.24    -0.04          58.36
# 79 2024-01-26        -4.36  CVCB3         3.07    -0.04           3.21
# 80 2024-01-26        -8.07  GOLL4         5.92    -0.08           6.44
#
#     qtd_teorica    variacao_rs Resultado
# 0     515117391   241889725.43     Subiu
# 1    1110559345   177515970.30     Subiu
# 2    2379877655  2140059393.53     Subiu
# 3     683452836   722946282.71     Subiu
# 4     187732538   138573955.06     Subiu
# ..          ...            ...       ...
# 76    533990587  -143635530.57    Desceu
# 77     94843047   -20810240.84    Desceu
# 78    853202347 -1807432634.46    Desceu
# 79    525582771   -73557408.06    Desceu
# 80    198184909  -102993202.62    Desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_Ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal = df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#          Data  var_dia_pct  Ativo  valor_final  Var_pct  valor_inicial  \
# 0  2024-01-26         5.20  USIM5         9.50     0.05           9.03
# 1  2024-01-26         2.40  CMIN3         6.82     0.02           6.66
# 2  2024-01-26         2.19  PETR3        41.96     0.02          41.06
# 3  2024-01-26         2.04  SUZB3        52.91     0.02          51.85
# 4  2024-01-26         2.03  CPFE3        37.10     0.02          36.36
# ..        ...          ...    ...          ...      ...            ...
# 76 2024-01-26        -2.45  CRFB3        10.71    -0.02          10.98
# 77 2024-01-26        -2.46  BHIA3         8.70    -0.02           8.92
# 78 2024-01-26        -3.63  RENT3        56.24    -0.04          58.36
# 79 2024-01-26        -4.36  CVCB3         3.07    -0.04           3.21
# 80 2024-01-26        -8.07  GOLL4         5.92    -0.08           6.44
#
#     qtd_teorica    variacao_rs Resultado              Nome
# 0     515117391   241889725.43     Subiu          Usiminas
# 1    1110559345   177515970.30     Subiu     CSN Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras
# 3     683452836   722946282.71     Subiu            Suzano
# 4     187732538   138573955.06     Subiu      CPFL Energia
# ..          ...            ...       ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu       Casas Bahia
# 78    853202347 -1807432634.46    Desceu          Localiza
# 79    525582771   -73557408.06    Desceu               CVC
# 80    198184909  -102993202.62    Desceu               GOL
#
# [81 rows x 10 columns]

# %%
df_principal = df_principal.merge(df_ChatGPTGEMINI, left_on='Nome', right_on='Nome da Empresa', how='left')
df_principal = df_principal.drop(columns=['Nome da Empresa'])
df_principal
# Out:
#          Data  var_dia_pct  Ativo  valor_final  Var_pct  valor_inicial  \
# 0  2024-01-26         5.20  USIM5         9.50     0.05           9.03
# 1  2024-01-26         2.40  CMIN3         6.82     0.02           6.66
# 2  2024-01-26         2.19  PETR3        41.96     0.02          41.06
# 3  2024-01-26         2.04  SUZB3        52.91     0.02          51.85
# 4  2024-01-26         2.03  CPFE3        37.10     0.02          36.36
# ..        ...          ...    ...          ...      ...            ...
# 76 2024-01-26        -2.45  CRFB3        10.71    -0.02          10.98
# 77 2024-01-26        -2.46  BHIA3         8.70    -0.02           8.92
# 78 2024-01-26        -3.63  RENT3        56.24    -0.04          58.36
# 79 2024-01-26        -4.36  CVCB3         3.07    -0.04           3.21
# 80 2024-01-26        -8.07  GOLL4         5.92    -0.08           6.44
#
#     qtd_teorica    variacao_rs Resultado              Nome          Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas        Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração         Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 3     683452836   722946282.71     Subiu            Suzano  Papel e Celulose
# 4     187732538   138573955.06     Subiu      CPFL Energia  Energia Elétrica
# ..          ...            ...       ...               ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil               NaN
# 77     94843047   -20810240.84    Desceu       Casas Bahia               NaN
# 78    853202347 -1807432634.46    Desceu          Localiza               NaN
# 79    525582771   -73557408.06    Desceu               CVC               NaN
# 80    198184909  -102993202.62    Desceu               GOL               NaN
#
#     Idade (Anos)
# 0          66.00
# 1          80.00
# 2          72.00
# 3          94.00
# 4         114.00
# ..           ...
# 76           NaN
# 77           NaN
# 78           NaN
# 79           NaN
# 80           NaN
#
# [81 rows x 12 columns]

# %%
df_principal = df_principal.rename(columns={'Idade (Anos)':'idade'}).copy()
df_principal
# Out:
#          Data  var_dia_pct  Ativo  valor_final  Var_pct  valor_inicial  \
# 0  2024-01-26         5.20  USIM5         9.50     0.05           9.03
# 1  2024-01-26         2.40  CMIN3         6.82     0.02           6.66
# 2  2024-01-26         2.19  PETR3        41.96     0.02          41.06
# 3  2024-01-26         2.04  SUZB3        52.91     0.02          51.85
# 4  2024-01-26         2.03  CPFE3        37.10     0.02          36.36
# ..        ...          ...    ...          ...      ...            ...
# 76 2024-01-26        -2.45  CRFB3        10.71    -0.02          10.98
# 77 2024-01-26        -2.46  BHIA3         8.70    -0.02           8.92
# 78 2024-01-26        -3.63  RENT3        56.24    -0.04          58.36
# 79 2024-01-26        -4.36  CVCB3         3.07    -0.04           3.21
# 80 2024-01-26        -8.07  GOLL4         5.92    -0.08           6.44
#
#     qtd_teorica    variacao_rs Resultado              Nome          Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas        Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração         Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 3     683452836   722946282.71     Subiu            Suzano  Papel e Celulose
# 4     187732538   138573955.06     Subiu      CPFL Energia  Energia Elétrica
# ..          ...            ...       ...               ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil               NaN
# 77     94843047   -20810240.84    Desceu       Casas Bahia               NaN
# 78    853202347 -1807432634.46    Desceu          Localiza               NaN
# 79    525582771   -73557408.06    Desceu               CVC               NaN
# 80    198184909  -102993202.62    Desceu               GOL               NaN
#
#     idade
# 0   66.00
# 1   80.00
# 2   72.00
# 3   94.00
# 4  114.00
# ..    ...
# 76    NaN
# 77    NaN
# 78    NaN
# 79    NaN
# 80    NaN
#
# [81 rows x 12 columns]

# %%
df_principal['Cat_idade'] = df_principal['idade'].apply(lambda x:'Mais de 100 anos' if x > 100 else ('Menos de 50 anos' if x < 50 else 'Entre 50 e 100'))
df_principal
# Out:
#          Data  var_dia_pct  Ativo  valor_final  Var_pct  valor_inicial  \
# 0  2024-01-26         5.20  USIM5         9.50     0.05           9.03
# 1  2024-01-26         2.40  CMIN3         6.82     0.02           6.66
# 2  2024-01-26         2.19  PETR3        41.96     0.02          41.06
# 3  2024-01-26         2.04  SUZB3        52.91     0.02          51.85
# 4  2024-01-26         2.03  CPFE3        37.10     0.02          36.36
# ..        ...          ...    ...          ...      ...            ...
# 76 2024-01-26        -2.45  CRFB3        10.71    -0.02          10.98
# 77 2024-01-26        -2.46  BHIA3         8.70    -0.02           8.92
# 78 2024-01-26        -3.63  RENT3        56.24    -0.04          58.36
# 79 2024-01-26        -4.36  CVCB3         3.07    -0.04           3.21
# 80 2024-01-26        -8.07  GOLL4         5.92    -0.08           6.44
#
#     qtd_teorica    variacao_rs Resultado              Nome          Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas        Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração         Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras    Petróleo e Gás
# 3     683452836   722946282.71     Subiu            Suzano  Papel e Celulose
# 4     187732538   138573955.06     Subiu      CPFL Energia  Energia Elétrica
# ..          ...            ...       ...               ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil               NaN
# 77     94843047   -20810240.84    Desceu       Casas Bahia               NaN
# 78    853202347 -1807432634.46    Desceu          Localiza               NaN
# 79    525582771   -73557408.06    Desceu               CVC               NaN
# 80    198184909  -102993202.62    Desceu               GOL               NaN
#
#     idade Cat. idade         Cat_idade
# 0   66.00      Subiu    Entre 50 e 100
# 1   80.00      Subiu    Entre 50 e 100
# 2   72.00      Subiu    Entre 50 e 100
# 3   94.00      Subiu    Entre 50 e 100
# 4  114.00      Subiu  Mais de 100 anos
# ..    ...        ...               ...
# 76    NaN    Estável    Entre 50 e 100
# 77    NaN    Estável    Entre 50 e 100
# 78    NaN    Estável    Entre 50 e 100
# 79    NaN    Estável    Entre 50 e 100
# 80    NaN    Estável    Entre 50 e 100
#
# [81 rows x 14 columns]

# %%
# Cálculos
maior = df_principal['variacao_rs'].max()
menor = df_principal['variacao_rs'].min()
media_total = df_principal['variacao_rs'].mean()
media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['variacao_rs'].mean()
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['variacao_rs'].mean()

# Imprimir resultados
print(f"Maior\t {maior:,.2f}")
print(f"Menor\t {menor:,.2f}")
print(f"Média\t {media_total:,.2f}")
print(f"Média de quem subiu\tR$ {media_subiu:,.2f}")
print(f"Média de quem desceu\tR$ {media_desceu:,.2f}")
# Out:
# Maior	 4,762,926,995.25
# Menor	 -1,807,432,634.46
# Média	 165,190,210.48
# Média de quem subiu	R$ 448,164,250.23
# Média de quem desceu	R$ -181,109,141.75

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#          Data  var_dia_pct  Ativo  valor_final  Var_pct  valor_inicial  \
# 0  2024-01-26         5.20  USIM5         9.50     0.05           9.03
# 1  2024-01-26         2.40  CMIN3         6.82     0.02           6.66
# 2  2024-01-26         2.19  PETR3        41.96     0.02          41.06
# 3  2024-01-26         2.04  SUZB3        52.91     0.02          51.85
# 4  2024-01-26         2.03  CPFE3        37.10     0.02          36.36
# 5  2024-01-26         1.98  PRIO3        45.69     0.02          44.80
# 6  2024-01-26         1.73  PETR4        39.96     0.02          39.28
# 7  2024-01-26         1.66  VALE3        69.50     0.02          68.37
# 8  2024-01-26         1.58  MULT3        28.19     0.02          27.75
# 9  2024-01-26         1.48  ITUB4        32.81     0.01          32.33
# 10 2024-01-26         1.43  RDOR3        27.56     0.01          27.17
# 11 2024-01-26         1.42  BRKM5        18.55     0.01          18.29
# 12 2024-01-26         1.42  AZUL4        14.27     0.01          14.07
# 13 2024-01-26         1.41  RRRP3        28.75     0.01          28.35
# 14 2024-01-26         1.34  EQTL3        35.32     0.01          34.85
# 15 2024-01-26         1.33  CSNA3        18.16     0.01          17.92
# 16 2024-01-26         1.28  YDUQ3        19.77     0.01          19.52
# 17 2024-01-26         1.28  UGPA3        28.31     0.01          27.95
# 18 2024-01-26         1.25  MRVE3         8.08     0.01           7.98
# 19 2024-01-26         1.15  ARZZ3        57.91     0.01          57.25
# 20 2024-01-26         1.04  BBDC4        15.52     0.01          15.36
# 21 2024-01-26         0.98  BEEF3         7.19     0.01           7.12
# 22 2024-01-26         0.97  PCAR3         4.14     0.01           4.10
# 23 2024-01-26         0.96  BRFS3        14.61     0.01          14.47
# 24 2024-01-26         0.88  VIVT3        51.20     0.01          50.75
# 25 2024-01-26         0.84  RAIL3        22.64     0.01          22.45
# 26 2024-01-26         0.82  CIEL3         4.90     0.01           4.86
# 27 2024-01-26         0.77  DXCO3         7.81     0.01           7.75
# 28 2024-01-26         0.74  TIMS3        17.52     0.01          17.39
# 29 2024-01-26         0.73  BRAP4        23.22     0.01          23.05
# 30 2024-01-26         0.72  LWSA3         5.55     0.01           5.51
# 31 2024-01-26         0.71  RECV3        23.83     0.01          23.66
# 32 2024-01-26         0.70  ITSA4        10.01     0.01           9.94
# 33 2024-01-26         0.68  BBAS3        56.97     0.01          56.59
# 34 2024-01-26         0.61  RADL3        26.16     0.01          26.00
# 35 2024-01-26         0.59  GOAU4        10.08     0.01          10.02
# 36 2024-01-26         0.59  CSAN3        18.57     0.01          18.46
# 37 2024-01-26         0.57  JBSS3        24.34     0.01          24.20
# 38 2024-01-26         0.48  MGLU3         2.08     0.00           2.07
# 39 2024-01-26         0.36  BBDC3        13.75     0.00          13.70
# 40 2024-01-26         0.27  GGBR4        21.84     0.00          21.78
# 41 2024-01-26         0.26  RAIZ4         3.74     0.00           3.73
# 42 2024-01-26         0.19  CPLE6        10.07     0.00          10.05
# 43 2024-01-26         0.12  VAMO3         8.18     0.00           8.17
#
#     qtd_teorica   variacao_rs Resultado                  Nome  \
# 0     515117391  241889725.43     Subiu              Usiminas
# 1    1110559345  177515970.30     Subiu         CSN Mineração
# 2    2379877655 2140059393.53     Subiu             Petrobras
# 3     683452836  722946282.71     Subiu                Suzano
# 4     187732538  138573955.06     Subiu          CPFL Energia
# 5     800010734  709687498.18     Subiu              PetroRio
# 6    4566445852 3103136291.22     Subiu             Petrobras
# 7    4196924316 4762926995.25     Subiu                  Vale
# 8     268505432  117732680.08     Subiu             Multiplan
# 9    4801593832 2297591984.33     Subiu         Itaú Unibanco
# 10   1168230366  453917907.01     Subiu             Rede D'Or
# 11    265877867   69054317.64     Subiu               Braskem
# 12    327593725   65452205.55     Subiu                  Azul
# 13    235665566   94204643.35     Subiu          3R Petroleum
# 14   1095587251  511671895.45     Subiu    Equatorial Energia
# 15    600865451  143220991.46     Subiu  Siderúrgica Nacional
# 16    289347914   72295838.99     Subiu                 YDUQS
# 17   1086411192  388705223.96     Subiu              Ultrapar
# 18    376187582   37525872.38     Subiu                   MRV
# 19     62305891   41021792.09     Subiu                Arezzo
# 20   5146576868  822148336.41     Subiu        Banco Bradesco
# 21    261036182   18214628.10     Subiu               Minerva
# 22    159430826    6340916.22     Subiu   Grupo Pão de Açúcar
# 23   1677525446  233045769.57     Subiu                   BRF
# 24    423091712  188965307.06     Subiu                  Vivo
# 25   1218352541  229771333.63     Subiu                  Rumo
# 26   1095462329   43657683.38     Subiu                 Cielo
# 27    302768240   18068446.61     Subiu                 Dexco
# 28    807896814  103972807.37     Subiu                   TIM
# 29    251003438   42238249.54     Subiu             Bradespar
# 30    393173139   15598886.65     Subiu               Locaweb
# 31    275005663   46201006.00     Subiu        PetroRecôncavo
# 32   5372783971  373853994.88     Subiu                Itaúsa
# 33   1420949112  546752087.99     Subiu       Banco do Brasil
# 34   1275798515  202352473.74     Subiu          RaiaDrogasil
# 35    660411219   39045606.94     Subiu    Metalúrgica Gerdau
# 36   1168097881  127229653.18     Subiu                 Cosan
# 37   1134986472  156573285.43     Subiu                   JBS
# 38   2867627068   28493619.27     Subiu        Magazine Luiza
# 39   1500728902   74019610.05     Subiu        Banco Bradesco
# 40   1118525506   65779607.10     Subiu                Gerdau
# 41   1193047233   11571106.42     Subiu                Raízen
# 42   1679335290   32069789.50     Subiu                 Copel
# 43    421383330    4131341.16     Subiu           Grupo Vamos
#
#                                     Segmento  idade Cat. idade  \
# 0                                 Siderurgia  66.00      Subiu
# 1                                  Mineração  80.00      Subiu
# 2                             Petróleo e Gás  72.00      Subiu
# 3                           Papel e Celulose  94.00      Subiu
# 4                           Energia Elétrica 114.00      Subiu
# 5                             Petróleo e Gás  15.00      Subiu
# 6                             Petróleo e Gás  72.00      Subiu
# 7                                  Mineração  55.00      Subiu
# 8                           Shopping Centers  45.00      Subiu
# 9                                      Banco  23.00      Subiu
# 10                                     Saúde  25.00      Subiu
# 11                              Petroquímica  46.00      Subiu
# 12                                   Aviação  15.00      Subiu
# 13                            Petróleo e Gás  10.00      Subiu
# 14                          Energia Elétrica 104.00      Subiu
# 15                                Siderurgia  77.00      Subiu
# 16                                  Educação  52.00      Subiu
# 17             Distribuidora de Combustíveis  98.00      Subiu
# 18                          Construção Civil  42.00      Subiu
# 19                        Varejo de Calçados  47.00      Subiu
# 20                                     Banco 122.00      Subiu
# 21                               Alimentação  54.00      Subiu
# 22                                    Varejo  75.00      Subiu
# 23                               Alimentação 115.00      Subiu
# 24                          Telecomunicações  25.00      Subiu
# 25                                 Logística  23.00      Subiu
# 26                        Meios de Pagamento  27.00      Subiu
# 27  Distribuidora de Materiais de Construção  45.00      Subiu
# 28                          Telecomunicações  30.00      Subiu
# 29                             Participações 107.00      Subiu
# 30                                Tecnologia  25.00      Subiu
# 31                            Petróleo e Gás   8.00      Subiu
# 32                             Participações  54.00      Subiu
# 33                                     Banco 214.00      Subiu
# 34                                 Farmácias  20.00      Subiu
# 35                                Siderurgia 126.00      Subiu
# 36                              Conglomerado  97.00      Subiu
# 37                               Alimentação  67.00      Subiu
# 38                                    Varejo  63.00      Subiu
# 39                                     Banco 122.00      Subiu
# 40                                Siderurgia 126.00      Subiu
# 41                                   Energia  11.00      Subiu
# 42                          Energia Elétrica  77.00      Subiu
# 43                                    Varejo  48.00      Subiu
#
#            Cat_idade
# 0     Entre 50 e 100
# 1     Entre 50 e 100
# 2     Entre 50 e 100
# 3     Entre 50 e 100
# 4   Mais de 100 anos
# 5   Menos de 50 anos
# 6     Entre 50 e 100
# 7     Entre 50 e 100
# 8   Menos de 50 anos
# 9   Menos de 50 anos
# 10  Menos de 50 anos
# 11  Menos de 50 anos
# 12  Menos de 50 anos
# 13  Menos de 50 anos
# 14  Mais de 100 anos
# 15    Entre 50 e 100
# 16    Entre 50 e 100
# 17    Entre 50 e 100
# 18  Menos de 50 anos
# 19  Menos de 50 anos
# 20  Mais de 100 anos
# 21    Entre 50 e 100
# 22    Entre 50 e 100
# 23  Mais de 100 anos
# 24  Menos de 50 anos
# 25  Menos de 50 anos
# 26  Menos de 50 anos
# 27  Menos de 50 anos
# 28  Menos de 50 anos
# 29  Mais de 100 anos
# 30  Menos de 50 anos
# 31  Menos de 50 anos
# 32    Entre 50 e 100
# 33  Mais de 100 anos
# 34  Menos de 50 anos
# 35  Mais de 100 anos
# 36    Entre 50 e 100
# 37    Entre 50 e 100
# 38    Entre 50 e 100
# 39  Mais de 100 anos
# 40  Mais de 100 anos
# 41  Menos de 50 anos
# 42    Entre 50 e 100
# 43  Menos de 50 anos

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#                                     Segmento   variacao_rs
# 0                                Alimentação  407833683.09
# 1                                    Aviação   65452205.55
# 2                                      Banco 3740512018.78
# 3                               Conglomerado  127229653.18
# 4                           Construção Civil   37525872.38
# 5              Distribuidora de Combustíveis  388705223.96
# 6   Distribuidora de Materiais de Construção   18068446.61
# 7                                   Educação   72295838.99
# 8                                    Energia   11571106.42
# 9                           Energia Elétrica  682315640.01
# 10                                 Farmácias  202352473.74
# 11                                 Logística  229771333.63
# 12                        Meios de Pagamento   43657683.38
# 13                                 Mineração 4940442965.55
# 14                          Papel e Celulose  722946282.71
# 15                             Participações  416092244.42
# 16                              Petroquímica   69054317.64
# 17                            Petróleo e Gás 6093288832.26
# 18                                     Saúde  453917907.01
# 19                          Shopping Centers  117732680.08
# 20                                Siderurgia  489935930.93
# 21                                Tecnologia   15598886.65
# 22                          Telecomunicações  292938114.42
# 23                                    Varejo   38965876.66
# 24                        Varejo de Calçados   41021792.09

# %%
df_analise_saldo = df_principal.groupby('Resultado')['variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado    variacao_rs
# 0    Desceu -6338819961.32
# 1   Estável           0.00
# 2     Subiu 19719227010.14

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y='variacao_rs', text='variacao_rs', title="Variações Reais por Resultado")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a3a220e8-9dbf-4d1a-9d75-b2599d86fa5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3a220e8-9dbf-4d1a-9d75-b2599d86fa5e")) {                    Plotly.newPlot(                        "a3a220e8-9dbf-4d1a-9d75-b2599d86fa5e",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003evariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[-6338819961.31535,0.0,19719227010.14191],"textposition":"auto","x":["Desceu","Est\u00e1vel","Subiu"],"xaxis":"x","y":[-6338819961.31535,0.0,19719227010.14191],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}] ...

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y='variacao_rs', text='variacao_rs', title="Variações Reais por Resultado")
z
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="66a7017a-bc0f-4db4-9816-d07ec6a6af48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66a7017a-bc0f-4db4-9816-d07ec6a6af48")) {                    Plotly.newPlot(                        "66a7017a-bc0f-4db4-9816-d07ec6a6af48",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003evariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":["R$ -6,338,819,961.32","R$ 0.00","R$ 19,719,227,010.14"],"textposition":"auto","x":["Desceu","Est\u00e1vel","Subiu"],"xaxis":"x","y":["R$ -6,338,819,961.32","R$ 0.00","R$ 19,719,227,010.14"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10 ...

# %%
fig = px.pie(df_analise_segmento, names='Segmento', values='variacao_rs', title='Variação Reais por Segmento')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f616290d-8460-418d-9256-19a219eb9c90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f616290d-8460-418d-9256-19a219eb9c90")) {                    Plotly.newPlot(                        "f616290d-8460-418d-9256-19a219eb9c90",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Segmento=%{label}\u003cbr\u003evariacao_rs=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Alimenta\u00e7\u00e3o","Avia\u00e7\u00e3o","Banco","Conglomerado","Constru\u00e7\u00e3o Civil","Distribuidora de Combust\u00edveis","Distribuidora de Materiais de Constru\u00e7\u00e3o","Educa\u00e7\u00e3o","Energia","Energia El\u00e9trica","Farm\u00e1cias","Log\u00edstica","Meios de Pagamento","Minera\u00e7\u00e3o","Papel e Celulose","Participa\u00e7\u00f5es","Petroqu\u00edmica","Petr\u00f3leo e G\u00e1s","Sa\u00fade","Shopping Centers","Siderurgia","Tecnologia","Telecomunica\u00e7\u00f5es","Varejo","Varejo de Cal\u00e7ados"],"legendgroup":"","name":"","showlegend":true,"values":[407833683.0924499,65452205.552800186,3740512018.7834516,127229653.18222687,37525872.37728388,388705223.95601785,18068446.60998324,72295838.98616095,11571106.417007603,682315640.0120441,202352473.73982856,229771333.63468358,43657683.37554085,4940442965.550434,722946282.7090385,416092244.423763,69054317.63603853,6093288832.2628355,453917907.01324,117732680.0784251,489935930.9283229,15598886.650556229,292938114.42357796,38965876.65542857,41021792.09077153],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222 ...

# %%
df_analise_cat_idade = df_principal.groupby('Cat_idade')['variacao_rs'].sum().reset_index()
df_analise_cat_idade
fig = px.bar(df_analise_cat_idade, x='Cat_idade', y='variacao_rs', text='variacao_rs', title='Variação Reais por Categoria de Idade')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4c573a39-5bbb-4075-89fd-a1fe18cfb9f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c573a39-5bbb-4075-89fd-a1fe18cfb9f2")) {                    Plotly.newPlot(                        "4c573a39-5bbb-4075-89fd-a1fe18cfb9f2",                        [{"alignmentgroup":"True","hovertemplate":"Cat_idade=%{x}\u003cbr\u003evariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[8304074831.856163,1201463729.4368875,3874868487.533511],"textposition":"auto","x":["Entre 50 e 100","Mais de 100 anos","Menos de 50 anos"],"xaxis":"x","y":[8304074831.856163,1201463729.4368875,3874868487.533511],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode ...
